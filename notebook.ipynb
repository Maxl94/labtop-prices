# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Introduction
#
# You have a role of ML Engineer in a large Online Computer Store.
#
# You have just received a new project and the associated, unknown data set in CSV Format.
#
# Your task is to create a model for predicting laptop price based on a selection of laptop characteristics in oder to support the Sales department in extension of the product range.
#
# To do this, analyze the training data set.

# %% [markdown]
# # Load and analyze the data
#
# First carry out an exploitative analysis: which variables have connections to the target variable? Which ones make sense from a business point of view?

# %% [markdown]
# # Data preparation
#
# - Prepare the data for a training.
# - Think about different possibilities, to use the full potential of the data (feature engineering).

# %% [markdown]
# # Model
#
# Make a selection of explanatory variables and then create a baseline prediction model of your choice (do not tune the model to provide the best possible results, the performance of the model is not important at this stage). Describe the performance of the model. Briefly explain the choice of the model.

# %% [markdown]
# # Evaluation
#
# Briefly explain the choice of the evaluation and the concept of the test/validation data to evaluate the model.
