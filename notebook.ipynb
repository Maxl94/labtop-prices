# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Introduction
#
# The laptop prices dataset contains several information about laptops and their prices. The goal is to predict the prices based on the available metadata.

# %% [markdown]
# # Load and analyse the data
#
# - Load the data from the dataset located under `../input/laptop-price/laptop_price.csv`
# - Futher more analys the data, with plots, tables etc.

# %% [markdown]
# # Data preparation
#
# - Prepare the data for a training.
# - Think about different possibilities, to use the full potential of the data

# %% [markdown]
# # Model
#
# - Create a model and train it

# %% [markdown]
# # Evaluation
#
# - Chose suitable metrics and evaluate your model
